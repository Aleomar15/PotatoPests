# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleomar15/PotatoPests/blob/main/PotatoCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os

# %%
# Evitando erros de OOM configurando o crescimento do consumo de memória da GPU
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Removendo imagens incoerentes

# %%
import cv2
import imghdr

# %%
data_dir = "/content/drive/MyDrive/Potato Pest Dataset"

# %%
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try:
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts:
                print('Está imagem não esta na lista{}'.format(image_path))
                os.remove(image_path)
        except Exception as e:
            print('Problema com imagem {}'.format(image_path))
            # os.remove(image_path)

# %% [markdown]
# # Carregando as imagens

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('/content/drive/MyDrive/Potato Pest Dataset')
# Out:
# Found 494 files belonging to 8 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# # Dimensionando dados

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
data.as_numpy_iterator().next()
# Out:
# (array([[[[9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           ...,
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01]],
#
#          [[9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           ...,
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01]],
#
#          [[9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           ...,
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01]],
#
#          ...,
#
#          [[9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           ...,
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01]],
#
#          [[9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           ...,
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01]],
#
#          [[9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           ...,
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01],
#           [9.96078432e-01, 9.96078432e-01, 9.96078432e-01]]],
#
#
#         [[[7.29411781e-01, 6.94117665e-01, 6.58823550e-01],
#           [7.03569233e-01, 6.68275118e-01, 6.32981002e-01],
#           [6.94883585e-01, 6.59589469e-01, 6.24295354e-01],
#           ...,
#           [3.72916669e-01, 3.37622553e-01, 3.02328438e-01],
#           [2.29304537e-01, 1.94010422e-01, 1.58716306e-01],
#           [1.96078435e-01, 1.60784319e-01, 1.25490203e-01]],
#
#          [[6.93964481e-01, 6.58670366e-01, 6.23376250e-01],
#           [7.16893911e-01, 6.81599796e-01, 6.46305680e-01],
#           [7.21085608e-01, 6.85791492e-01, 6.50497377e-01],
#           ...,
#           [3.39407891e-01, 3.04113775e-01, 2.68819660e-01],
#           [2.94564635e-01, 2.59270519e-01, 2.23976403e-01],
#           [3.46047789e-01, 3.10753673e-01, 2.75459558e-01]],
#
#          [[6.68780625e-01, 6.33486509e-01, 5.98192394e-01],
#           [7.16716230e-01, 6.81422114e-01, 6.46127999e-01],
#           [7.32001901e-01, 6.96707785e-01, 6.61413670e-01],
#           ...,
#           [3.69358927e-01, 3.34064811e-01, 2.98770666e-01],
#           [4.24094886e-01, 3.88800770e-01, 3.53506655e-01],
#           [5.21783113e-01, 4.86488968e-01, 4.51194853e-01]],
#
#          ...,
#
#          [[1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           ...,
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01]],
#
#          [[1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           ...,
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01]],
#
#          [[1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           ...,
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01],
#           [1.29411772e-01, 1.29411772e-01, 1.29411772e-01]]],
#
#
#         [[[5.96078455e-01, 6.19607866e-01, 5.80392182e-01],
#           [6.25612736e-01, 6.49142146e-01, 6.09926462e-01],
#           [6.59298420e-01, 6.82827830e-01, 6.43612146e-01],
#           ...,
#           [4.69929546e-01, 3.56204033e-01, 2.94224888e-01],
#           [5.78063726e-01, 4.64338243e-01, 4.09436285e-01],
#           [6.66666687e-01, 5.52941203e-01, 4.98039216e-01]],
#
#          [[6.26072288e-01, 6.49601698e-01, 6.10386014e-01],
#           [6.45338833e-01, 6.68868244e-01, 6.29652560e-01],
#           [6.66083217e-01, 6.89612627e-01, 6.50396943e-01],
#           ...,
#           [5.53456485e-01, 4.42457736e-01, 3.85399431e-01],
#           [6.24588311e-01, 5.13589561e-01, 4.58687574e-01],
#           [6.72120094e-01, 5.61121345e-01, 5.06219387e-01]],
#           [8.77144635e-02, 2.39215687e-01, 1.56862754e-02],
#           [8.77144635e-02, 2.39215687e-01, 1.56862754e-02]],
#
#          [[6.27451017e-02, 1.96078435e-01, 0.00000000e+00],
#           [6.32046536e-02, 1.95618868e-01, 0.00000000e+00],
#           [6.66666701e-02, 1.92156866e-01, 0.00000000e+00],
#           ...,
#           [1.13725491e-01, 2.43137255e-01, 2.74509806e-02],
#           [1.07077204e-01, 2.35294119e-01, 2.00061277e-02],
#           [1.07077204e-01, 2.35294119e-01, 2.00061277e-02]],
#
#          [[6.66666701e-02, 1.92156866e-01, 0.00000000e+00],
#           [6.66666701e-02, 1.92156866e-01, 0.00000000e+00],
#           [6.66666701e-02, 1.92156866e-01, 0.00000000e+00],
#           ...,
#           [1.05882354e-01, 2.39215687e-01, 3.92156877e-02],
#           [8.62745121e-02, 2.43137255e-01, 3.52941193e-02],
#           [1.09803922e-01, 2.39215687e-01, 2.35294122e-02]],
#
#          ...,
#
#          [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           ...,
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#          [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           ...,
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#          [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           ...,
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]]],
#        dtype=float32),
#  array([7, 4, 4, 6, 6, 7, 1, 6, 2, 1, 0, 1, 1, 7, 3, 2, 5, 7, 6, 7, 0, 1,
#         0, 1, 2, 2, 7, 6, 0, 6, 0, 6], dtype=int32))

# %% [markdown]
# # Dividindo Dados

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

# %%
train_size
# Out:
# 11

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
train = train.map(lambda x, y: (x, tf.one_hot(y, depth=8)))
val = val.map(lambda x, y: (x, tf.one_hot(y, depth=8)))
test = test.map(lambda x, y: (x, tf.one_hot(y, depth=8)))

# %% [markdown]
# # Contruindo o modelo de CNN(ou Deep Learning)

# %%
train
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 8), dtype=tf.float32, name=None))>

# %%
from tensorflow.keras.models import Sequential #Sequential = ResNet-50
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (5, 5),1, activation='relu', input_shape=(256, 256, 3)))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Conv2D(32, (5, 5),1, activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Conv2D(16, (5, 5),1, activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(8, activation='softmax'))

# %%
optimizer = Adam(learning_rate=0.001)  # Ajuste a taxa de aprendizado
model.compile(optimizer=optimizer,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 252, 252, 16)      1216
#
#  max_pooling2d (MaxPooling2  (None, 126, 126, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 122, 122, 32)      12832
#
#  max_pooling2d_1 (MaxPoolin  (None, 61, 61, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 57, 57, 16)        12816
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 256)               3211520
#
#  dense_1 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 3240440 (12.36 MB)
# Trainable params: 3240440 (12.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Treino

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 11/11 [==============================] - 17s 293ms/step - loss: 2.4294 - accuracy: 0.1818 - val_loss: 1.8956 - val_accuracy: 0.2917
# Epoch 2/20
# 11/11 [==============================] - 5s 368ms/step - loss: 1.9663 - accuracy: 0.2528 - val_loss: 1.8854 - val_accuracy: 0.2812
# Epoch 3/20
# 11/11 [==============================] - 6s 468ms/step - loss: 1.9478 - accuracy: 0.2784 - val_loss: 2.0880 - val_accuracy: 0.2708
# Epoch 4/20
# 11/11 [==============================] - 6s 426ms/step - loss: 1.8450 - accuracy: 0.3466 - val_loss: 1.9001 - val_accuracy: 0.5000
# Epoch 5/20
# 11/11 [==============================] - 5s 389ms/step - loss: 1.7258 - accuracy: 0.4688 - val_loss: 1.6074 - val_accuracy: 0.3750
# Epoch 6/20
# 11/11 [==============================] - 5s 390ms/step - loss: 1.5711 - accuracy: 0.4290 - val_loss: 1.4311 - val_accuracy: 0.5208
# Epoch 7/20
# 11/11 [==============================] - 9s 716ms/step - loss: 1.3512 - accuracy: 0.5455 - val_loss: 1.2233 - val_accuracy: 0.6562
# Epoch 8/20
# 11/11 [==============================] - 5s 361ms/step - loss: 1.1260 - accuracy: 0.6165 - val_loss: 0.8359 - val_accuracy: 0.7604
# Epoch 9/20
# 11/11 [==============================] - 8s 710ms/step - loss: 0.8988 - accuracy: 0.6875 - val_loss: 0.9934 - val_accuracy: 0.5938
# Epoch 10/20
# 11/11 [==============================] - 5s 361ms/step - loss: 0.7815 - accuracy: 0.7131 - val_loss: 0.6806 - val_accuracy: 0.7396
# Epoch 11/20
# 11/11 [==============================] - 8s 647ms/step - loss: 0.6459 - accuracy: 0.7642 - val_loss: 0.3932 - val_accuracy: 0.8646
# Epoch 12/20
# 11/11 [==============================] - 5s 366ms/step - loss: 0.4496 - accuracy: 0.8693 - val_loss: 0.4226 - val_accuracy: 0.8542
# Epoch 13/20
# 11/11 [==============================] - 5s 390ms/step - loss: 0.3233 - accuracy: 0.8864 - val_loss: 0.2933 - val_accuracy: 0.9167
# Epoch 14/20
# 11/11 [==============================] - 5s 362ms/step - loss: 0.2652 - accuracy: 0.9176 - val_loss: 0.4396 - val_accuracy: 0.8854
# Epoch 15/20
# 11/11 [==============================] - 8s 653ms/step - loss: 0.2376 - accuracy: 0.9034 - val_loss: 0.1862 - val_accuracy: 0.9375
# Epoch 16/20
# 11/11 [==============================] - 5s 391ms/step - loss: 0.1308 - accuracy: 0.9602 - val_loss: 0.1239 - val_accuracy: 0.9896
# Epoch 17/20
# 11/11 [==============================] - 7s 500ms/step - loss: 0.1096 - accuracy: 0.9744 - val_loss: 0.1098 - val_accuracy: 0.9479
# Epoch 18/20
# 11/11 [==============================] - 5s 361ms/step - loss: 0.1264 - accuracy: 0.9659 - val_loss: 0.1140 - val_accuracy: 0.9792
# Epoch 19/20
# 11/11 [==============================] - 8s 643ms/step - loss: 0.2255 - accuracy: 0.9659 - val_loss: 0.0674 - val_accuracy: 0.9896
# Epoch 20/20
# 11/11 [==============================] - 5s 362ms/step - loss: 0.2363 - accuracy: 0.9716 - val_loss: 0.2928 - val_accuracy: 0.9271

# %% [markdown]
# # Medindo e mostrando performace

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Perdas(Loss)', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Acurácia(Accuracy)', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # Avaliando a CNN

# %%
from tensorflow.keras.metrics import Precision, Recall, F1Score, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
f1 = F1Score(average='macro')
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    y = y.reshape(-1, 1)  # Remodela os rótulos para (batch_size, 1)
    yhat = yhat.reshape(-1, 1)  # Remodela as previsões para (batch_size, 1)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
    f1.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 110ms/step

# %%
print(pre.result(), re.result(), acc.result(), f1.result())
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(0.9375, shape=(), dtype=float32) tf.Tensor(0.9921875, shape=(), dtype=float32) tf.Tensor(0.23021582, shape=(), dtype=float32)
